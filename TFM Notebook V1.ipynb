# %% [markdown]
# Pre-text  processing to remove number of features:
# 1) convert all text to lowercase
# 2) remove any whitespace
# 3) remove stop-word
# 4) stem all words
# 5) lemmatize all words

# %%
#Load libraries
import pandas as pd
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import spacy
import textblob

# %%
#load data set into Pandas
df_corpus = pd.read_csv("C:/Users/Ryanw/Desktop/TFM/GoldmanSachs_2018_2022.csv")

# %%
#Remove Mentions '@' and "#" and URLs from tweets
import re

#Function to remove mentions
def remove_regExp(text):
    text = re.sub('@[\w]+','',text) #remove users
    text = re.sub(r"\S*https?:\S*",'', text) #remove URLs
    text = re.sub('#[\w]+','',text) #remove hastags
    return text

#Call function to clean data
df_corpus['content_clean'] = df_corpus['content_clean'].apply(lambda x: remove_regExp(str(x)))

# %%
# 3 Data pipline, remove white spaces, puctuation, stopwords and or currency and lemmatize words

# load spacy english large dictionary
from textblob import Word  

nlp = spacy.load('en_core_web_sm')

#Function to remove punc, stopwords, spaces, currency
def clean_pipeline(text):
    text = nlp(text)
    output = []
    for token in text:
        if not token.is_punct and not token.is_stop and not token.is_space and not token.is_currency :         
           output.append((token.lemma_.lower()))
    else: return ' '.join(output)

#Apply cleaning pipeline to content_clean
df_corpus['content_clean'] = df_corpus['content'].apply(lambda x: clean_pipeline(x))

# %%
#Determine the language of the tweet
#from langdetect import detect

#Function for language detection
#def language(text):
       #try:
           #lang = detect(text)
           #lang = [str(lang).split(':')[0][0:]]
           #return lang
       #except: None
    
#Assign languages to the DF
#df_corpus['Tweet_Language'] = df_corpus['content_clean'].apply(lambda x: language(x))

# %%
#Remove whitespaces
df_corpus['content_clean'] = df_corpus['content_clean'].apply(lambda x: x.strip())

#Add Tweet length
df_corpus['Tweet_LEN']= df_corpus['content_clean'].apply(lambda x: len(x))

#drop all blank rows
df_corpus = df_corpus[df_corpus['lang'] =='en']

# %%
#spellcheck
from textblob import Word

def spell_Check(text):
    output =[]
    words = text.split()

    for word in words:
        spell = Word(word).correct()
        output.append(spell)
    return ' '.join(output)

df_corpus['content_clean']= df_corpus['content_clean'].apply(lambda x: spell_Check(x))

# %%
#Wordnet sentiment analysis
from nltk.corpus import wordnet as wnet
from nltk.corpus import sentiwordnet as swnet

# %% [markdown]
# # TextBlob sentiment analysis

# %%
#Textblob sentiment analysis
from textblob import TextBlob

#make df text

def stirng_setting(text):
    transform = str(text)
    return transform

#Convert content_clean to string format
df_corpus['content_clean'] = df_corpus['content_clean'].apply(stirng_setting)

#sentiment classification: positive, neutral, negative
def sent_class(num):
    if num> 0:
        return "Positive"
    elif num < 0:
        return "Negative"
    else: return "Neutral"

#Subjectivity classification: Objective, subjective 
def sub_class(num):
    if num > 0:
        return "Subjective"
    else: return "Objective"


#sentiment calculation
def senti_calculation(text):
    try:
        return TextBlob(text).sentiment.polarity
    except:
        return None


#Subjective or Objective
def subj_calculation(text):
    try:
        return TextBlob(text).subjectivity
    except:
        return None

#Add sentimet score to DF
df_corpus['TextBlob_Sentiment_Score'] = df_corpus['content_clean'].apply(senti_calculation)

#Add sentiment classiification to text
df_corpus['TextBlob_Score_Class'] = df_corpus.TextBlob_Sentiment_Score.apply(sent_class)

#add subjectivity score to dataframe
df_corpus["TextBlob_Subj_Score"] = df_corpus['content_clean'].apply(subj_calculation)

#Add sentiment classiification to text
df_corpus['TextBlob_Subj_Class'] = df_corpus.TextBlob_Subj_Score.apply(sub_class)

# %% [markdown]
# # VADER sentiment analysis testing

# %%
# VADER Sentiment analysis - Better analysis for social media as it has more related to puncuation and emojis
from nltk.sentiment.vader import SentimentIntensityAnalyzer

#initiate instance
vader = SentimentIntensityAnalyzer()

#VADER sentiment analysis
df_corpus['VADER_Score'] = df_corpus.content_clean.apply(lambda x: vader.polarity_scores(x))

#Vader sentiment score:
df_corpus['VADER_Score'] = df_corpus['VADER_Score'].apply(lambda d: d['compound'])

#Vader sentiment classification:
df_corpus['Vader_Score_Class'] = df_corpus.VADER_Score.apply(sent_class)

# %% [markdown]
# # Topic Modeling

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

#vecotrize content_clean
corpus = df_corpus.content_clean.tolist()
vec = CountVectorizer()
matrix = vec.fit_transform(corpus)

#initialize LDA
lda = LatentDirichletAllocation(n_components = 2)
lda.fit(matrix)

lda.components_
# Out:
# array([[ 54.12143901,  86.10843367,   0.50993485, ...,   1.43608826,
#           1.49582685,   1.49582685],
#        [  0.87856099, 160.89156633,   2.49006515, ...,   0.56391174,
#           0.50417315,   0.50417315]])

# %%
vec.vocabulary_
# Out:
# {'we': 18898,
#  'indoctrinate': 9531,
#  'think': 17507,
#  'people': 13258,
#  'need': 12189,
#  'wheel': 19015,
#  'moment': 11806,
#  'call': 3410,
#  'expert': 6956,
#  'drive': 6123,
#  'pump': 14129,
#  'cliff': 4033,
#  'assess': 2025,
#  'assure': 2051,
#  'indigenous': 9522,
#  'bit': 2725,
#  'feel': 7230,
#  'powerless': 13734,
#  'able': 1148,
#  'remove': 14682,
#  'up': 18383,
#  'cap': 3474,
#  'race': 14263,
#  'reductions': 14526,
#  'nonsense': 12364,
#  'obviously': 12531,
#  'work': 19239,
#  'shit': 15826,
#  'bag': 2286,
#  'like': 10739,
#  'is': 9946,
#  'regardless': 14574,
#  'politically': 13607,
#  'current': 5076,
#  'system': 17137,
#  'divide': 5929,
#  'amp': 1654,
#  'conquer': 4480,
#  'all': 1526,
#  'target': 17210,
#  '142': 183,
#  '97': 1089,
#  'met': 11544,
#  '118': 128,
#  '65': 901,
#  '107': 78,
#  '39': 695,
#  'now': 12449,
#  'if': 9283,
#  'stock': 16658,
#  'short': 15848,
#  'week': 18942,
#  '35': 660,
#  'or': 12739,
#  'anniversary': 1729,
#  'black': 2751,
#  'monday': 11813,
#  '1987': 334,
#  'possible': 13698,
#  'red': 14508,
#  'october': 12551,
#  'with': 19163,
#  'elliott': 6421,
#  'iii': 9297,
#  'relentless': 14636,
#  'brutal': 3199,
#  'probable': 13911,
#  'start': 16549,
#  'friday': 7783,
#  'east': 6258,
#  'haven': 8777,
#  'it': 9983,
#  'environmental': 6646,
#  'justice': 10211,
#  'town': 17741,
#  'golden': 8272,
#  'sacks': 15248,
#  'polite': 13602,
#  'encroaches': 6525,
#  'land': 10465,
#  'false': 7106,
#  'agreement': 1437,
#  'll': 10830,
#  'toxic': 17743,
#  'water': 18871,
#  'marine': 11244,
#  'life': 10709,
#  'pesticide': 13336,
#  'tell': 17323,
#  'clean': 4001,
#  'mess': 11538,
#  'home': 9030,
#  'price': 13857,
#  'fall': 7100,
#  'authorize': 2163,
#  'usage': 18420,
#  'residential': 14805,
#  'area': 1912,
#  'tweed': 18037,
#  'new': 12250,
#  'airport': 1463,
#  'face': 7043,
#  'money': 11826,
#  'politician': 13609,
#  'pay': 13170,
#  'political': 13605,
#  'pawn': 13167,
#  'boy': 3019,
#  'spray': 16450,
#  'dirty': 5743,
#  'come': 4220,
#  'west': 18979,
#  'end': 6528,
#  'infrastructure': 9609,
#  'partners': 13096,
#  'know': 10386,
#  'etc': 6769,
#  'get': 8123,
#  'fat': 7166,
#  'expense': 6950,
#  'taxpayers': 17231,
#  'game': 7965,
#  'foot': 7579,
#  'dear': 5256,
#  'watson': 18882,
#  '200': 383,
#  'cash': 3591,
#  'hack': 8632,
#  'ask': 1998,
#  'lithium': 10806,
#  'lithiumshortage': 10809,
#  'brand': 3058,
#  'live': 10818,
#  '40': 719,
#  'year': 19387,
#  'ago': 1433,
#  'glad': 8187,
#  'draw': 6093,
#  'big': 2651,
#  'salary': 15285,
#  'proud': 14060,
#  'young': 19417,
#  'generation': 8054,
#  'eliminate': 6415,
#  'free': 7743,
#  'speech': 16386,
#  'future': 7907,
#  'secure': 15568,
#  'bright': 3136,
#  'weird': 18960,
#  'promote': 13998,
#  'sweet': 17084,
#  'literally': 10801,
#  'attempt': 2096,
#  'relevant': 14639,
#  'whilst': 19036,
#  'rest': 14843,
#  'world': 19266,
#  'finance': 7338,
#  'industry': 9546,
#  'joke': 10141,
#  'thank': 17413,
#  'but': 3330,
#  'bye': 3361,
#  'inflation': 9583,
#  'bad': 2275,
#  'market': 11254,
#  'fun': 7866,
#  'anybody': 1794,
#  'retirement': 14886,
#  'alive': 1523,
#  '2020': 421,
#  'right': 14988,
#  'mind': 11653,
#  'trust': 17965,
#  'material': 11340,
#  'sector': 15564,
#  'worth': 19295,
#  'billion': 2676,
#  'trillion': 17892,
#  'decade': 5274,
#  'perfect': 13278,
#  'accuracy': 1231,
#  'recommend': 14480,
#  'closing': 4074,
#  'take': 17171,
#  'sullen': 16917,
#  'hand': 8682,
#  'the': 17424,
#  'go': 8242,
#  'mule': 11986,
#  'true': 17929,
#  'american': 1632,
#  'dream': 6099,
#  'gainfully': 7947,
#  'employ': 6490,
#  'afford': 1387,
#  'buy': 3343,
#  'access': 1202,
#  'easy': 6262,
#  'credit': 4887,
#  'house': 9128,
#  'build': 3233,
#  'good': 8337,
#  'job': 10113,
#  'income': 9461,
#  'sustainable': 17047,
#  'hey': 8928,
#  'client': 4030,
#  'spoon': 16440,
#  'ape': 1811,
#  'day': 5226,
#  'shot': 15868,
#  'sell': 15616,
#  'order': 12750,
#  'gap': 7977,
#  'pound': 13720,
#  'sterling': 16615,
#  'dollar': 5980,
#  'bull': 3249,
#  'achieve': 1241,
#  'parity': 13065,
#  'well': 18965,
#  'strong': 16784,
#  'fundamental': 7871,
#  '10': 45,
#  '000': 1,
#  'small': 16112,
#  'business': 3305,
#  'cost': 4747,
#  'program': 13963,
#  'cuyahoga': 5103,
#  'community': 4292,
#  'college': 4184,
#  'offer': 12569,
#  'education': 6325,
#  'entrepreneur': 6637,
#  'application': 1858,
#  'accept': 1199,
#  'begin': 2515,
#  'january': 10040,
#  '2023': 436,
#  'by': 3359,
#  'recognize': 14479,
#  'boss': 2989,
#  'welcome': 18962,
#  'party': 13099,
#  'of': 12561,
#  'careerreentry': 3543,
#  'assistance': 2040,
#  'sac': 15240,
#  'look': 10907,
#  'break': 3077,
#  'returnutah': 14899,
#  'returntowork': 14898,
#  'returnship': 14896,
#  'returnshipprogram': 14897,
#  'relationship': 14624,
#  'mtglq': 11970,
#  'investors': 9898,
#  'examine': 6872,
#  'efficient': 6337,
#  'way': 18893,
#  'load': 10843,
#  'date': 5203,
#  'quantum': 14209,
#  'computer': 4366,
#  'task': 17215,
#  'loading': 10845,
#  'non': 12349,
#  'classical': 3990,
#  'memory': 11495,
#  'excavation': 6875,
#  'department': 5472,
#  'card': 3529,
#  'tier': 17589,
#  'car': 3510,
#  'give': 8179,
#  'runaround': 15207,
#  'panel': 13021,
#  'discuss': 5796,
#  'power': 13730,
#  'representation': 14754,
#  'snipped': 16166,
#  'highlight': 8942,
#  'importance': 9391,
#  'diversity': 5915,
#  'team': 17251,
#  'develop': 5593,
#  'product': 13932,
#  'user': 18436,
#  'diversityintech': 5917,
#  'cold': 4157,
#  'social': 16193,
#  'security': 15574,
#  'foregone': 7611,
#  'solidifies': 16246,
#  'transitory': 17815,
#  'kind': 10330,
#  'thirst': 17515,
#  'trap': 17830,
#  'ad': 1284,
#  'set': 15690,
#  'online': 12662,
#  'saving': 15396,
#  'account': 1221,
#  'definitely': 5363,
#  'refer': 14536,
#  'plan': 13476,
#  'ran': 14317,
#  'guy': 8619,
#  'suuuuch': 17060,
#  'fraud': 7727,
#  'human': 9167,
#  'technologies': 17281,
#  'second': 15547,
#  'consecutive': 4487,
#  'builders': 3237,
#  'innovations': 9658,
#  'summit': 16928,
#  'pioneer': 13441,
#  'technology': 17283,
#  'meaningful': 11415,
#  'change': 3737,
#  'numattech': 12461,
#  'gsinnovator': 8555,
#  'mask': 11304,
#  'hope': 9078,
#  'thief': 17499,
#  'liar': 10683,
#  'great': 8453,
#  'episode': 6661,
#  'love': 10952,
#  'hold': 9010,
#  'music': 12036,
#  'bird': 2713,
#  'feather': 7210,
#  'organizedcrime': 12772,
#  'criminalcartel': 4910,
#  'store': 16708,
#  'conversation': 4617,
#  'rise': 15017,
#  'operate': 12698,
#  'russia': 15219,
#  'escape': 6724,
#  'producer': 13931,
#  'in': 9412,
#  'drummer': 6148,
#  'camera': 3430,
#  'state': 16559,
#  'thought': 17534,
#  'mr': 11964,
#  'proper': 14018,
#  'see': 15582,
#  'receive': 14451,
#  'distinguished': 5890,
#  'greeting': 8499,
#  'project': 13976,
#  'organize': 12770,
#  'competition': 4321,
#  'nassika': 12134,
#  'participation': 13086,
#  'nationality': 12142,
#  'capital': 3481,
#  'city': 3953,
#  'exploratory': 6972,
#  'undergraduate': 18179,
#  'student': 16802,
#  'frenchman': 7772,
#  'senior': 15637,
#  'career': 3539,
#  'development': 5596,
#  'opportunity': 12716,
#  'available': 2181,
#  'financial': 7342,
#  'service': 15685,
#  'expand': 6931,
#  '19': 276,
#  'division': 5935,
#  'firm': 7414,
#  'major': 11107,
#  'apply': 1861,
#  'talk': 17185,
#  'core': 4674,
#  'maurice': 11364,
#  'close': 4070,
#  'phone': 13384,
#  'issue': 9973,
#  'principle': 13879,
#  'hear': 8816,
#  'loud': 10943,
#  'you': 19414,
#  'wallet': 18790,
#  'fix': 7435,
#  'favor': 7186,
#  'cancel': 3444,
#  'apple': 1847,
#  'twitching': 18048,
#  'samson': 15312,
#  'fuck': 7829,
#  'to': 17646,
#  'ride': 14968,
#  'sum': 16922,
#  'company': 4304,
#  'beginning': 2516,
#  'kid': 10312,
#  'today': 17649,
#  'simple': 15973,
#  'refund': 14564,
#  'family': 7115,
#  'emergency': 6463,
#  '800': 997,
#  'will': 19103,
#  'interest': 9783,
#  'installment': 9713,
#  'utf': 18451,
#  'vote': 18724,
#  'tip': 17630,
#  'balance': 2306,
#  'scenario': 15441,
#  'hire': 8972,
#  'hit': 8989,
#  '1800': 252,
#  'manage': 11157,
#  'fund': 7870,
#  'naked': 12099,
#  'rob': 15053,
#  'inappropriate': 9423,
#  'lending': 10633,
#  'record': 14488,
#  '87': 1040,
#  'generate': 8053,
#  'bonus': 2943,
#  'shareholder': 15765,
#  'millionaire': 11643,
#  'stuff': 16809,
#  'fine': 7374,
#  '16': 218,
#  '4b': 783,
#  'rich': 14955,
#  'morris': 11903,
#  'room': 15119,
#  'ok': 12606,
#  'white': 19050,
#  'yes': 19400,
#  'racial': 14268,
#  'solidarity': 16245,
#  'hell': 8872,
#  'real': 14396,
#  'buttwipe': 3341,
#  '2024': 438,
#  'legally': 10605,
#  '12': 136,
#  'month': 11869,
#  '24': 509,
#  'intent': 9771,
#  'lawyer': 10538,
#  'touch': 17728,
#  'nascent': 12128,
#  'rid': 14965,
#  'custody': 5090,
#  'merrily': 11535,
#  'lynch': 11024,
#  'breakaway': 3078,
#  'old': 12612,
#  'school': 15458,
#  'taylor': 17238,
#  'street': 16755,
#  'estate': 6758,
#  'want': 18811,
#  'between': 2623,
#  'share': 15762,
#  'oh': 12593,
#  'confuse': 4447,
#  'hispanic': 8980,
#  'lately': 10498,
#  'publish': 14109,
#  'decision': 5300,
#  'open': 12685,
#  'reduce': 14522,
#  'production': 13933,
#  'million': 11642,
#  'barrel': 2405,
#  'raise': 14305,
#  'oil': 12598,
#  '104': 73,
#  '2022': 433,
#  'level': 10669,
#  '110': 109,
#  'quarter': 14217,
#  'ridiculous': 14976,
#  'hongkong': 9064,
#  'drop': 6133,
#  '30': 602,
#  'stop': 16686,
#  'invite': 9907,
#  'fear': 7200,
#  'poisonous': 13578,
#  'kill': 10316,
#  'name': 12106,
#  'clifford': 4034,
#  'ted': 17292,
#  'cruz': 4972,
#  'wife': 19092,
#  'board': 2892,
#  'tramp': 17792,
#  'ugly': 18091,
#  'spit': 16418,
#  'fact': 7060,
#  'fr': 7701,
#  'learn': 10570,
#  'brazil': 3071,
#  'tula': 17999,
#  'return': 14893,
#  'mean': 11413,
#  'country': 4792,
#  'rule': 15193,
#  'law': 10527,
#  'worry': 19285,
#  'md': 11406,
#  'quit': 14250,
#  'mary': 11299,
#  'happy': 8714,
#  'cryptonews': 5013,
#  'marcus': 11224,
#  'holder': 9012,
#  'pass': 13104,
#  'away': 2207,
#  'allow': 1547,
#  'redeem': 14514,
#  'accumulate': 1229,
#  'point': 13573,
#  'basically': 2428,
#  'steal': 16580,
#  'sir': 16010,
#  'wire': 19150,
#  'sentiment': 15650,
#  'indicator': 9516,
#  'negative': 12198,
#  'near': 12176,
#  'must': 12052,
#  'straight': 16723,
#  'alternative': 1573,
#  'tiny': 17629,
#  'trade': 17760,
#  'marketsentiment': 11272,
#  'peakpessimism': 13198,
#  'gettingbullish': 8132,
#  'jeff': 10063,
#  'carried': 3571,
#  'speculator': 16385,
#  'affiliation': 1380,
#  'had': 8635,
#  'find': 7372,
#  'interlocutor': 9794,
#  'grievance': 8509,
#  'experience': 6952,
#  'help': 8880,
#  'investment': 9886,
#  'jeopardy': 10074,
#  'group': 8532,
#  'inch': 9438,
#  'strategist': 16743,
#  'household': 9130,
#  'foreigner': 7615,
#  'value': 18493,
#  '100': 46,
#  'make': 11110,
#  'net': 12228,
#  'purchase': 14143,
#  'similar': 15968,
#  'magnitude': 11085,
#  'bearmarket': 2478,
#  'selloff': 15619,
#  'recession': 14461,
#  'model': 11777,
#  'suggest': 16904,
#  'liable': 10682,
#  'nominal': 12344,
#  'decline': 5308,
#  'peak': 13197,
#  '15': 192,
#  'canada': 3439,
#  'view': 18619,
#  'risk': 15020,
#  'estimate': 6761,
#  'tilt': 17607,
#  'downside': 6063,
#  'dump': 6180,
#  'let': 10655,
#  'bunch': 3272,
#  'retail': 14866,
#  'trader': 17763,
#  'sweden': 17080,
#  'favorite': 7191,
#  'deep': 5325,
#  'green': 8475,
#  'correct': 4719,
#  'answer': 1748,
#  'accord': 1218,
#  'research': 14789,
#  'scandinavian': 15424,
#  'birthplace': 2720,
#  'specify': 16376,
#  'remarkably': 14664,
#  'high': 8937,
#  'percentage': 13268,
#  'streaming': 16752,
#  '58': 852,
#  '2021': 428,
#  '2007': 393,
#  'anymore': 1796,
#  'regard': 14572,
#  'precious': 13771,
#  'bow': 3012,
#  'miss': 11724,
#  'bankers': 2348,
#  'meeting': 11460,
#  'forget': 7636,
#  'alarm': 1479,
#  'wrong': 19322,
#  'time': 17611,
#  'understand': 18201,
#  'impact': 9354,
#  'electrification': 6396,
#  'determine': 5576,
#  'head': 8794,
#  'dividend': 5932,
#  'brows': 3188,
#  'just': 10207,
#  'check': 3796,
#  'leave': 10580,
#  'hard': 8722,
#  'comprehend': 4358,
#  'write': 19317,
#  'mislead': 11716,
#  'manipulation': 11182,
#  'content': 4559,
#  'solve': 16256,
#  'beverage': 2625,
#  'position': 13688,
#  'fuel': 7846,
#  'am': 1592,
#  'amcnotleave': 1616,
#  'express': 6986,
#  'fire': 7403,
#  'covid': 4823,
#  'unvaccinated': 18379,
#  'isn': 9960,
#  'ny': 12482,
#  'sanction': 15318,
#  'lift': 10723,
#  'widen': 19086,
#  'say': 15407,
#  'anaemic': 1671,
#  'mild': 11619,
#  'thredup': 17546,
#  'customer': 5092,
#  'long': 10899,
#  'nearly': 12180,
#  'delete': 5394,
#  'email': 6438,
#  'spasm': 16352,
#  '41': 737,
#  'september': 15660,
#  '17': 234,
#  '29': 571,
#  'categories': 3617,
#  'angry': 1715,
#  'surprised': 17020,
#  'representative': 14756,
#  'clue': 4092,
#  'intentionally': 9774,
#  'guess': 8585,
#  'flat': 7463,
#  'lie': 10705,
#  'glimpse': 8200,
#  'acre': 1258,
#  'adjacent': 1308,
#  'part': 13077,
#  'museum': 12034,
#  'nature': 12158,
#  'science': 15467,
#  'downtown': 6066,
#  'dallas': 5144,
#  'led': 10588,
#  'mortification': 11914,
#  'office': 12576,
#  'camps': 3437,
#  'burn': 3286,
#  'concede': 4375,
#  'ifweburnyouburnwithus': 9284,
#  'iwbybwu': 10008,
#  'follow': 7556,
#  'dragon': 6083,
#  'agenda': 1415,
#  'italians': 9985,
#  'melon': 11480,
#  'valuevo': 18497,
#  'disappointed': 5755,
#  'florida': 7510,
#  'martha': 11289,
#  'vineyards': 18642,
#  'stay': 16574,
#  'taxes': 17227,
#  'building': 3238,
#  'disaster': 5759,
#  'immigrant': 9337,
#  'rebuild': 14437,
#  'gold': 8266,
#  'watch': 18865,
#  'man': 11156,
#  'significantly': 15943,
#  'cut': 5096,
#  'forecast': 7603,
#  'bounce': 3001,
#  'downgrade': 6057,
#  'weakening': 18901,
#  'micro': 11575,
#  'remain': 14658,
#  'bluish': 2881,
#  'forward': 7675,
#  'pilot': 13425,
#  'structural': 16788,
#  'supply': 16982,
#  'story': 16716,
#  'note': 12414,
#  'common': 4265,
#  'us': 18417,
#  'masha': 11302,
#  'among': 1650,
#  'death': 5258,
#  'cause': 3635,
#  'protest': 14054,
#  'internet': 9810,
#  'block': 2828,
#  'government': 8380,
#  'spread': 16452,
#  'video': 18612,
#  'medium': 11457,
#  'arrest': 1947,
#  'result': 14860,
#  'shutdown': 15902,
#  'voice': 18699,
#  'opera': 12697,
#  'mahsaamini': 11089,
#  'iranprotests2022': 9920,
#  'اعتصابات_سراسری': 19480,
#  'agree': 1435,
#  'term': 17360,
#  'lease': 10574,
#  'centenary': 3677,
#  'large': 10482,
#  'private': 13895,
#  'equity': 6684,
#  'commitment': 4259,
#  'report': 14745,
#  'insider': 9687,
#  'privateequity': 13896,
#  'fundraise': 7877,
#  'est': 6753,
#  'regulations': 14596,
#  'tighten': 17594,
#  'economy': 6296,
#  'shut': 15901,
#  'dissatisfaction': 5875,
#  'unauthorized': 18131,
#  'happen': 8709,
#  'reverse': 14916,
#  'charge': 3755,
#  'layout': 10546,
#  'terrible': 17369,
#  'dispute': 5861,
#  '290': 572,
#  'transaction': 17797,
#  'merchant': 11515,
#  'provide': 14068,
#  'falsity': 7109,
#  'mistress': 11743,
#  'investor': 9897,
#  'june': 10197,
#  'who': 19064,
#  'turkey': 18016,
#  'sour': 16316,
#  'six': 16020,
#  'tar': 17207,
#  'hello': 8876,
#  'fraudsters': 7734,
#  'remember': 14667,
#  'hilarious': 8949,
#  'lay': 10541,
#  'banker': 2347,
#  'criticize': 4933,
#  'contribute': 4597,
#  'heavily': 8843,
#  'gems': 8034,
#  'wake': 18775,
#  'reap': 14418,
#  'sew': 15704,
#  '500': 797,
#  '600': 880,
#  'landing': 10469,
#  'fed': 7215,
#  'aggressive': 1427,
#  'rate': 14348,
#  'tame': 17195,
#  'probably': 13912,
#  'push': 14167,
#  'apt': 1885,
#  'base': 2419,
#  'banking': 2349,
#  'txt': 18059,
#  'platform': 13498,
#  'corporate': 4709,
#  'europeanunion': 6812,
#  'bankingoption': 2358,
#  'bank': 2346,
#  'crept': 4899,
#  'hi': 8930,
#  'try': 17981,
#  'transfer': 17803,
#  'pm': 13559,
#  'show': 15879,
#  'bet': 2610,
#  'solomon': 16252,
#  'hate': 8764,
#  'patrick': 13144,
#  'cantlay': 3472,
#  'play': 13510,
#  'flag': 7444,
#  'devil': 5604,
#  'outfit': 12826,
#  'not': 12406,
#  'disappointment': 5757,
#  'bring': 3144,
#  'vision': 18675,
#  'north': 12384,
#  'ltd': 10981,
#  'age': 1411,
#  'friend': 7791,
#  'crash': 4868,
#  'sex1': 15708,
#  'woman': 19191,
#  'assault': 2017,
#  'grass': 8438,
#  'male': 11140,
#  'lawsuit': 10536,
#  'insist': 9695,
#  'apartment': 1807,
#  'picture': 13405,
#  'female': 7249,
#  'employee': 6492,
#  'lingered': 10766,
#  'complaint': 4334,
#  'read': 14387,
#  'join': 10135,
#  'wise': 19154,
#  'choice': 3885,
#  'happened': 8710,
#  'rendering': 14691,
#  '83': 1022,
#  'skyscraper': 16048,
#  '45': 756,
#  '50': 796,
#  'twin': 18042,
#  'clot': 4077,
#  'panic': 13022,
#  'stockmarket': 16663,
#  'morning': 11901,
#  'passively': 13116,
#  'hour': 9126,
#  'trading': 17771,
#  'turn': 18021,
#  'sandp500': 15329,
#  '3600': 671,
#  '4300': 749,
#  'federalreserve': 7219,
#  'interstate': 9827,
#  'originally': 12783,
#  'cautious': 3642,
#  'buying': 3348,
#  'idea': 9261,
#  'locally': 10859,
#  'goldmansach': 8290,
#  'indian': 9506,
#  'explore': 6973,
#  'avenue': 2186,
#  'businessman': 3319,
#  'smallbusinesse': 16117,
#  'ashore': 1987,
#  'bearing': 2477,
#  'contrarians': 4591,
#  'hole': 9016,
#  'es': 6721,
#  '727': 950,
#  'metaverse': 11552,
#  'web': 18924,
#  'perspective': 13326,
#  'gas': 7989,
#  'food': 7566,
#  'space': 16339,
#  'covid19': 4824,
#  'requirement': 14783,
#  'mayor': 11381,
#  'declare': 5306,
#  'vaccine': 18473,
#  'mandate': 11165,
#  'optional': 12736,
#  'bigapple': 2653,
#  'berg': 2587,
#  'rtitbot': 15174,
#  'revise': 14923,
#  'expectation': 6938,
#  '75bps': 973,
#  'nov': 12441,
#  '50bps': 817,
#  'dec': 5273,
#  '25bps': 538,
#  'jan': 10034,
#  'central': 3680,
#  'approximate': 1881,
#  'number': 12462,
#  'university': 18301,
#  'organic': 12762,
#  'farm': 7145,
#  'connect': 4473,
#  'china': 3855,
#  'analyst': 1678,
#  'commodity': 4264,
#  'managing': 11163,
#  'director': 5738,
#  'structures': 16791,
#  'clash': 3985,
#  'handed': 8685,
#  'afjnorthamerica': 1392,
#  'lead': 10554,
#  'stream': 16751,
#  'finding': 7373,
#  'deploying': 5487,
#  'low': 10963,
#  'yield': 19404,
#  'environment': 6645,
#  'register': 14585,
#  'fbwr88jdx6': 7197,
#  'filling': 7327,
#  'kept': 10284,
#  'resolve': 14820,
#  'complication': 4344,
#  'nice': 12286,
#  'working': 19249,
#  'so': 16180,
#  'everyday': 6845,
#  'accountant': 1224,
#  'accountable': 1223,
#  'whatsoever': 19010,
#  '25': 524,
#  'asia': 1990,
#  'justify': 10218,
#  'path': 13132,
#  'insight': 9690,
#  '114': 122,
#  'phenomena': 13368,
#  'rebuke': 14440,
#  'devoured': 5613,
#  'page': 12972,
#  '273': 555,
#  'telispectragence': 17322,
#  'unstoppable': 18359,
#  'lord': 10930,
#  'creator': 4881,
#  'phenomenon': 13369,
#  'tasha': 17214,
#  'hydrate': 9222,
#  'dig': 5664,
#  'midnight': 11602,
#  'fucking': 7835,
#  'savings': 15398,
#  'request': 14778,
#  'act': 1261,
#  'file': 7320,
#  'lock': 10863,
#  'reason': 14423,
#  'initiate': 9636,
#  'refuse': 14568,
#  'release': 14630,
#  'predict': 13781,
#  'bitcoin': 2728,
#  'dip': 5725,
#  'cryptocurrency': 4990,
#  'cryptocrash': 4984,
#  'growth': 8542,
#  'gross': 8526,
#  'domestic': 5989,
#  'increase': 9480,
#  'economist': 6294,
#  'include': 9451,
#  'hatzius': 8771,
#  'compare': 4307,
#  'previously': 13854,
#  'realize': 14409,
#  ...}

# %%
features = vec.get_feature_names_out()

# %%
for tid, topic in enumerate(lda.components_):
    print('topic: ', tid)
    print("word IDs: ", topic.argsort()[:-5:-1])
    print("words: ",[features[i] for i in topic.argsort()[:-5:-1]])
    print("prob: ", [topic[i] for i in topic.argsort()[:-5:-1]])
# Out:
# topic:  0
# word IDs:  [ 8272 15248 11254  3343]
# words:  ['golden', 'sacks', 'market', 'buy']
# prob:  [2878.788304124221, 2159.240488002344, 856.5160846831951, 779.3569960619042]
# topic:  1
# word IDs:  [13258 11826 10739 12189]
# words:  ['people', 'money', 'like', 'need']
# prob:  [1806.950247127295, 1592.2861796881118, 1436.101897581055, 1234.7482090008891]

# %% [markdown]
# # Topic modelling with TDIDF Vectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

lda =LatentDirichletAllocation(n_components=10,topic_word_prior=.01)
vec = TfidfVectorizer()

matrix2 = vec.fit_transform(corpus)

lda.fit(matrix2)
features = vec.get_feature_names_out()

for tid, topic in enumerate(lda.components_):
    print('Topic: ',tid)
    print('Word IDs: ', topic.argsort()[:-5:-1])
    print('words: ', [features[i] for i in topic.argsort()[:-5:-1]])
# Out:
# Topic:  0
# Word IDs:  [ 9785  3263  6487 16475]
# words:  ['interesting', 'bullshit', 'empire', 'squad']
# Topic:  1
# Word IDs:  [ 5212 16252 10113 17965]
# words:  ['david', 'solomon', 'job', 'trust']
# Topic:  2
# Word IDs:  [15826 10739  6263  8272]
# words:  ['shit', 'like', 'eat', 'golden']
# Topic:  3
# Word IDs:  [11826 13170  1629 13258]
# words:  ['money', 'pay', 'america', 'people']
# Topic:  4
# Word IDs:  [16881  8272  8542  3774]
# words:  ['suck', 'golden', 'growth', 'chart']
# Topic:  5
# Word IDs:  [16658 11254  3774 17413]
# words:  ['stock', 'market', 'chart', 'thank']
# Topic:  6
# Word IDs:  [ 8817  9967 16686 19266]
# words:  ['heargaza', 'israel', 'stop', 'world']
# Topic:  7
# Word IDs:  [ 8337 19191  9946 11156]
# words:  ['good', 'woman', 'is', 'man']
# Topic:  8
# Word IDs:  [ 2828 12286  6856  8872]
# words:  ['block', 'nice', 'evil', 'hell']
# Topic:  9
# Word IDs:  [ 7829  8272  2728 15248]
# words:  ['fuck', 'golden', 'bitcoin', 'sacks']

# %% [markdown]
# #clean up function
# from sklearn.feature_extraction._stop_words import ENGLISH_STOP_WORDS
# from string import punctuation as punctuation
# allowed_tags = ['VBP','VB','VBG','JJ','NN','RB']
#
# def clean_data(text):
#     output =[]
#     words = nltk.tokenize.word_tokenize(text)
#     words_tags = nltk.pos_tag(words)
#     for w,t in words_tags:
#         if w in punc:
#             words.remove(w)
#         elif w in ENGLISH_STOP_WORDS:
#             words.remove(w)
#         elif t not in allowed_tags:
#             words.remove(w)
#         output.append(w)
#     return ' '.join(output)
#
# df_corpus['clean_Data'] = df_corpus['content'].apply(lambda x: clean_data(str(x)))

# %%
from sklearn.feature_extraction.text import CountVectorizer
vec = CountVectorizer()
matrix_x=vec.fit_transform(df_corpus.content_clean.tolist())

features = vec.get_feature_names_out()
lda = LatentDirichletAllocation(n_components=5)
lda.fit(matrix_x)

#sentiment analysis
from nltk.corpus import wordnet as wn
from nltk.corpus import sentiwordnet as swn

for tid, topics in enumerate(lda.components_):
    top_words = [features[i] for i in topics.argsort()[:-10:-1]]
    print(top_words)
    score = 0
    for w in top_words:
        senti_synset = swn.senti_synset(wn.synsets(w)[0].name())
        score+= senti_synset.pos_score()-senti_synset.neg_score()
    print('Sentiment Score: ',score)
# Out:
# ['people', 'new', 'black', 'year', 'change', 'global', 'sarscov2', 'need', 'know']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\Ryanw\Desktop\TFM\TFM Notebook.ipynb Cell 22 in <cell line: 13>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Ryanw/Desktop/TFM/TFM%20Notebook.ipynb#X62sZmlsZQ%3D%3D?line=15'>16</a> score = 0
#      <a href='vscode-notebook-cell:/c%3A/Users/Ryanw/Desktop/TFM/TFM%20Notebook.ipynb#X62sZmlsZQ%3D%3D?line=16'>17</a> for w in top_words:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Ryanw/Desktop/TFM/TFM%20Notebook.ipynb#X62sZmlsZQ%3D%3D?line=17'>18</a>     senti_synset = swn.senti_synset(wn.synsets(w)[0].name())
#      <a href='vscode-notebook-cell:/c%3A/Users/Ryanw/Desktop/TFM/TFM%20Notebook.ipynb#X62sZmlsZQ%3D%3D?line=18'>19</a>     score+= senti_synset.pos_score()-senti_synset.neg_score()
#      <a href='vscode-notebook-cell:/c%3A/Users/Ryanw/Desktop/TFM/TFM%20Notebook.ipynb#X62sZmlsZQ%3D%3D?line=19'>20</a> print('Sentiment Score: ',score)
#
# IndexError: list index out of range
